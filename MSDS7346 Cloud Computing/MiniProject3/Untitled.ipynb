# %%
import sys
separator='\t'

data = 'Syslog-Sample'
for line in [x.strip() for x in open(data).readlines()]:
    dateTime = line[0:15]
    print ('%s%s%d' % (dateTime,separator, 1))
# Out:
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# Nov 05 12:28:12	1
# ...

# %%
dateTime
# Out:
# 'Nov 05 12:29:02'

# %%
import sys
separator='\t'

def read_input(file):
    for line in file:
        yield line.split()

data = read_input('Syslog-Sample')
dateTime = ' '.join(line[0:15])
print ('%s%s%d' % (dateTime, separator, 1))
# Out:
# N o v   0 5   1 2 : 2 9 : 0 2	1

# %%
import sys

def read_input(file):
    for line in open(file).readlines():
        yield line.split()

separator='\t'

data = read_input('Syslog-Sample')
for words in line:
    word = ' '.join(words[0:3])
    print ('%s%s%d' % (word, separator, 1))
# Out:
# N	1
# o	1
# v	1
#  	1
# 0	1
# 5	1
#  	1
# 1	1
# 2	1
# :	1
# 2	1
# 9	1
# :	1
# 0	1
# 2	1
#  	1
# S	1
# o	1
# h	1
# a	1
# i	1
# l	1
# s	1
# -	1
# M	1
# B	1
# P	1
# .	1
# f	1
# r	1
# o	1
# n	1
# t	1
# i	1
# e	1
# r	1
# l	1
# o	1
# c	1
# a	1
# l	1
# .	1
# n	1
# e	1
# t	1
#  	1
# .	1
# /	1
# g	1
# e	1
# n	1
# e	1
# r	1
# a	1
# t	1
# e	1
# -	1
# l	1
# o	1
# g	1
# .	1
# s	1
# h	1
# [	1
# 2	1
# 4	1
# 5	1
# 3	1
# 8	1
# ]	1
# :	1
#  	1
# S	1
# E	1
# V	1
# E	1
# R	1
# E	1
# :	1
#  	1
# U	1
# n	1
# a	1
# b	1
# l	1
# e	1
#  	1
# t	1
# o	1
#  	1
# c	1
# o	1
# m	1
# p	1
# l	1
# e	1
# t	1
# e	1
#  	1
# t	1
# r	1
# a	1
# n	1
# s	1
# a	1
# c	1
# t	1
# i	1
# o	1
# n	1
#  	1
# -	1
#  	1
# O	1
# u	1
# t	1
#  	1
# o	1
# f	1
#  	1
# m	1
# e	1
# m	1
# o	1
# r	1
# y	1
